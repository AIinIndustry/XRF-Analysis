# %%
import torch

print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0))
# Out:
# True
# NVIDIA GeForce RTX 4060

# %%
import multiel_spectra as ms
import numpy as np

#Generate the incident spectra
Prim, brem = ms.Primary_gen(30, 46, 0.1, "casim", "nist", 1, 9, "Mo", [('Be', 0.127), ('Air', 10)])

# %%
#Compute a multiel-spectra with high number of counts and low noise
final_spectra, present_peaks, els_perc, decal_params = ms.spectra_gen(np.array([38,25,13,0,8,7]), Prim, brem, s_counts = 30000,n_counts = 30000,b_counts = 1000, c_counts = 1000,  escape = True, sum = True, decal = True,  char_r = 15, brem_r = 15,noise_f = 1000 )
# Out:
# (600,) (600,)
#     <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="cc793214-a4de-4b88-b563-7b749b2d5783">Loading BokehJS ...</span>
#     </div>
#   <div id="f5077c5d-d7b4-434e-aab1-f17f9f31dd19" data-root-id="p1011" style="display: contents;"></div>
